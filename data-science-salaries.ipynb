# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# File path of the dataset
data = '/kaggle/input/data-science-salaries-2023/ds_salaries.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(data) 

# Display the first few rows of the dataset
df.head()

# Check the shape of the dataset
df.shape

# Check the column names and data types
df.info()

# Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# ...

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
plt.figure(figsize=(18, 8))
sns.countplot(x='job_title', data=df)
plt.xticks(rotation=90)
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.title('Distribution of Job Titles')
plt.show()

# %%
plt.figure(figsize=(18, 8))
sns.countplot(x='employment_type', data=df)
plt.xlabel('Employment Type')
plt.ylabel('Count')
plt.title('Distribution of Employment Types')
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.countplot(x='company_location', data=df)
plt.xticks(rotation=90)
plt.xlabel('Company Location')
plt.ylabel('Count')
plt.title('Distribution of Company Locations')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='company_size', data=df)
plt.xticks(rotation=90)
plt.xlabel('Company Size')
plt.ylabel('Count')
plt.title('Distribution of Company Sizes')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='remote_ratio', data=df)
plt.xticks(rotation=90)
plt.xlabel('Remote Work Ratio')
plt.ylabel('Count')
plt.title('Distribution of Remote Work Ratio')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='work_year', data=df)
plt.xticks(rotation=90)
plt.xlabel('Work Year')
plt.ylabel('Count')
plt.title('Distribution of Work Years')
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.countplot(x='employee_residence', data=df)
plt.xticks(rotation=90)
plt.xlabel('Employee Residence')
plt.ylabel('Count')
plt.title('Distribution of Employee Residences')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='salary_currency', data=df)
plt.xticks(rotation=90)
plt.xlabel('Salary Currency')
plt.ylabel('Count')
plt.title('Distribution of Salary Currencies')
plt.show()

# %%
plt.figure(figsize=(12, 4))
sns.histplot(df['salary'], bins=10)
plt.xlabel('Salary')
plt.ylabel('Count')
plt.title('Distribution of Salaries')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['salary_in_usd'], bins=20)
plt.xlabel('Salary in USD')
plt.ylabel('Count')
plt.title('Distribution of Salaries in USD')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='experience_level', data=df)
plt.xticks(rotation=90)
plt.xlabel('Experience Level')
plt.ylabel('Count')
plt.title('Distribution of Experience Levels')
plt.show()

# %%
# Correlation analysis
correlation = df.corr()
print(correlation)

# Summary statistics of salary by job title
salary_by_job_title = df.groupby('job_title')['salary'].agg(['mean', 'median', 'min', 'max'])
print(salary_by_job_title)
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.094724       0.228290     -0.236430
# salary         -0.094724  1.000000      -0.023676      0.028731
# salary_in_usd   0.228290 -0.023676       1.000000     -0.064171
# remote_ratio   -0.236430  0.028731      -0.064171      1.000000
#                                         mean    median     min      max
# job_title
# 3D Computer Vision Researcher  120000.000000   35000.0   10000   400000
# AI Developer                   137181.818182  108000.0    6000   300000
# AI Programmer                   55000.000000   55000.0   40000    70000
# AI Scientist                   275312.500000  122500.0   12000  1500000
# Analytics Engineer             151352.621359  143860.0    7500   289800
# ...                                      ...       ...     ...      ...
# Research Engineer              162752.810811  155000.0   60000   293000
# ...

# %%
# Calculate the correlation matrix
correlation = df.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# /tmp/ipykernel_33/3862453422.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()

# %%
# Grouping and aggregation by job_title
salary_by_job_title = df.groupby('job_title')['salary'].agg(['mean', 'median', 'min', 'max'])
print(salary_by_job_title)
# Out:
#                                         mean    median     min      max
# job_title
# 3D Computer Vision Researcher  120000.000000   35000.0   10000   400000
# AI Developer                   137181.818182  108000.0    6000   300000
# AI Programmer                   55000.000000   55000.0   40000    70000
# AI Scientist                   275312.500000  122500.0   12000  1500000
# Analytics Engineer             151352.621359  143860.0    7500   289800
# ...                                      ...       ...     ...      ...
# Research Engineer              162752.810811  155000.0   60000   293000
# Research Scientist             160768.890244  150000.0   23000   450000
# Software Data Engineer          75000.000000   75000.0   50000   100000
# Staff Data Analyst              15000.000000   15000.0   15000    15000
# Staff Data Scientist           105000.000000  105000.0  105000   105000
#
# [93 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Select the relevant features and target variable
features = ['work_year', 'experience_level', 'employment_type', 'job_title', 'remote_ratio']
target = 'salary'

# Encode categorical features using one-hot encoding
encoded_df = pd.get_dummies(df[features], drop_first=True)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(encoded_df, df[target], test_size=0.2, random_state=42)

# Build and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model using mean squared error
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 167387525025.40994

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the Random Forest regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions using Random Forest model
y_pred_rf = rf_model.predict(X_test)

# Calculate the Mean Squared Error (MSE) using Random Forest model
mse_rf = mean_squared_error(y_test, y_pred_rf)
print("Mean Squared Error (Random Forest):", mse_rf)
# Out:
# Mean Squared Error (Random Forest): 316318636725.93024
